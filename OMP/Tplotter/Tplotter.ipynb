# %%
import matplotlib.pyplot as plt
import numpy as np

f = open("../A-100-30.txt", "r")

arr = f.read().split(";")
arr = arr[:-1]

datapoints= np.array(arr,dtype=float)
xpoints = np.arange(0, len(datapoints))

plt.plot(xpoints, datapoints)
plt.show()
